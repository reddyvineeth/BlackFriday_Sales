# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r'C:\Users\vinee\OneDrive\Desktop\FProjects\BF_FP.csv')

# %%
data.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
data.dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                        int64
# dtype: object

# %%
data.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
data['Product_Category_2'].mean()
# Out:
# 9.842329251122386

# %%
data['Product_Category_2'].median()
# Out:
# 9.0

# %%
data['Product_Category_2'].mode()
# Out:
# 0    8.0
# dtype: float64

# %%
def a(b):
    x = data[b].mean()
    y = data[b].median()
    z = data[b].mode()
    print('The mean for a column %s is %f' %(b, x))
    print('The median for a column %s is %f' %(b, y))
    print('The mode for a column %s is %f' %(b, z))

# %%
a('Product_Category_2')
# Out:
# The mean for a column Product_Category_2 is 9.842329
# The median for a column Product_Category_2 is 9.000000
# The mode for a column Product_Category_2 is 8.000000

# %%
a('Product_Category_3')
# Out:
# The mean for a column Product_Category_3 is 12.668243
# The median for a column Product_Category_3 is 14.000000
# The mode for a column Product_Category_3 is 16.000000

# %%
data['Product_Category_2'].replace(np.nan,data['Product_Category_2'].mean(),inplace = True)

# %%
data['Product_Category_3'].replace(np.nan,data['Product_Category_3'].mean(),inplace = True)

# %%
data.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %%
data.head()
#all the null values have been replaced and now the data is ready to clean
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0            9.842329           12.668243      8370
# 1            6.000000           14.000000     15200
# ...

# %%
sns.countplot(data['Gender'])
#clearly bar graph below indicates that males are purchasing more items than the females

# %%
sns.countplot(data['Age'])
#age group between 26-35 are more in number of buying items

# %%
sns.distplot(data['Occupation'])
#people with occupation 4 are buying more

# %%
sns.countplot(data['City_Category'])
#city B has more in number

# %%
sns.countplot(data['Stay_In_Current_City_Years'])
#people are residing max in particular city is for one year

# %%
sns.barplot(x = 'Stay_In_Current_City_Years', y = 'Purchase' , data = data)

# %%
sns.countplot(data['Marital_Status'])

# %%
sns.barplot(x = 'Marital_Status', y = 'Purchase', data = data)
#clearly we can see though there are more number of unmarried people but the purchase is same for both married and unmarried people

# %%
sns.countplot(data['Product_Category_1'])

# %%
sns.distplot(data['Product_Category_1'])

# %%
sns.boxplot(data['Product_Category_1'])
#values above 17.5 are outliers

# %%
sns.barplot( x = 'Product_Category_1', y = 'Purchase', data = data )

# %%
sns.distplot(data['Product_Category_2'])

# %%
sns.boxplot(data['Product_Category_2'])

# %%
sns.barplot( x = 'Product_Category_2', y = 'Purchase', data = data)
sns.set(rc={'figure.figsize':(20,8.27)})

# %%
sns.boxplot(data['Product_Category_3'])

# %%
sns.barplot(x = 'Product_Category_3', y = 'Purchase', data = data)

# %%
sns.barplot(x = 'City_Category',y = 'Purchase', data = data)
#City_Category 'C' has more no of purchase than the rest of the cities.

# %%
sns.barplot( x = 'Age', y = 'Purchase', data = data)
#purchase rate for age group between 51-55 is higher

# %%
sns.barplot(x = 'Gender', y = 'Purchase', data = data)

# %%
data.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
x = data.drop(['User_ID','Product_ID','Purchase'],axis = 1)

# %%
x.head()
# Out:
#   Gender   Age  Occupation City_Category Stay_In_Current_City_Years  \
# 0      F  0-17          10             A                          2
# 1      F  0-17          10             A                          2
# 2      F  0-17          10             A                          2
# 3      F  0-17          10             A                          2
# 4      M   55+          16             C                         4+
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3
# 0               0                   3            9.842329           12.668243
# 1               0                   1            6.000000           14.000000
# 2               0                  12            9.842329           12.668243
# 3               0                  12           14.000000           12.668243
# 4               0                   8            9.842329           12.668243

# %%
y = data['Purchase']

# %%
y.head()
# Out:
# 0     8370
# 1    15200
# 2     1422
# 3     1057
# 4     7969
# Name: Purchase, dtype: int64

# %%
x = pd.get_dummies(x)

# %%
x.head()
# Out:
#    Occupation  Marital_Status  Product_Category_1  Product_Category_2  \
# 0          10               0                   3            9.842329
# 1          10               0                   1            6.000000
# 2          10               0                  12            9.842329
# 3          10               0                  12           14.000000
# 4          16               0                   8            9.842329
#
#    Product_Category_3  Gender_F  Gender_M  Age_0-17  Age_18-25  Age_26-35  \
# 0           12.668243         1         0         1          0          0
# 1           14.000000         1         0         1          0          0
# 2           12.668243         1         0         1          0          0
# 3           12.668243         1         0         1          0          0
# 4           12.668243         0         1         0          0          0
#
#                ...                Age_51-55  Age_55+  City_Category_A  \
# ...

# %%
from sklearn import preprocessing

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
lr.coef_
# Out:
# array([   6.47355074,  -71.32692543, -407.0200931 ,  -85.53183576,
#          77.40925153, -252.39587971,  252.39587971, -546.89460785,
#        -206.8467644 ,   -7.49915961,   97.17104934,   78.41669476,
#         398.5112535 ,  187.14153426, -294.70499703, -121.12119475,
#         415.82619178,  -37.2739874 ,   -8.8198678 ,   32.80720961,
#          -3.63745786,   16.92410345])

# %%
lr.intercept_
# Out:
# 11167.4575450206

# %%
predictions = lr.predict(x_test)

# %%
predictions
# Out:
# array([11685.62351142,  6747.42486312,  9966.9602529 , ...,
#        12052.73008135, 11375.00063149,  9106.00974026])

# %%
plt.scatter(y_test,predictions)
#clearly from the graph we can see the predictions are very deviating

# %%
from sklearn import metrics

# %%
dataframe = pd.DataFrame(lr.coef_,x.columns,columns=['coeff'])

# %%
dataframe
# Out:
#                                     coeff
# Occupation                       6.473551
# Marital_Status                 -71.326925
# Product_Category_1            -407.020093
# Product_Category_2             -85.531836
# Product_Category_3              77.409252
# Gender_F                      -252.395880
# Gender_M                       252.395880
# Age_0-17                      -546.894608
# Age_18-25                     -206.846764
# Age_26-35                       -7.499160
# Age_36-45                       97.171049
# Age_46-50                       78.416695
# Age_51-55                      398.511254
# Age_55+                        187.141534
# City_Category_A               -294.704997
# City_Category_B               -121.121195
# City_Category_C                415.826192
# Stay_In_Current_City_Years_0   -37.273987
# Stay_In_Current_City_Years_1    -8.819868
# Stay_In_Current_City_Years_2    32.807210
# Stay_In_Current_City_Years_3    -3.637458
# ...

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

rms = sqrt(mean_squared_error(y_test,predictions))

# %%
rms
# Out:
# 4689.842457596896

# %%
import xgboost as xgb

# %%
boost_params = {'eval_metric': 'rmse'}

# %%
xg_reg = xgb.XGBRegressor(objective ='reg:linear', colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 20, alpha = 10, n_estimators = 1000)

# %%
xg_reg.fit(x_train,y_train)
# Out:
# [14:49:31] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(alpha=10, base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=0.3, gamma=0,
#        importance_type='gain', learning_rate=0.1, max_delta_step=0,
#        max_depth=20, min_child_weight=1, missing=None, n_estimators=1000,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=None, subsample=1, verbosity=1)

# %%
preds = xg_reg.predict(x_test)

# %%
rmse = np.sqrt(mean_squared_error(y_test, preds))

# %%
rmse
# Out:
# 2864.599911998502

# %%
xgb.plot_importance(xg_reg)
plt.rcParams['figure.figsize'] = [5, 5]
plt.show()
